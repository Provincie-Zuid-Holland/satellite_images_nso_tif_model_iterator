# %%
import geopandas as gdp
from shapely import geometry

# %%
gdp.read_file("E:/output/Coepelduynen_segmentations_development/20220922_110546_SV2-01_SV_RD_11bit_RGBI_50cm_Voorhout_natura2000_coepelduynen_cropped_ndvi_height_randomforest_classifier_v1_3_vegetation_sand.shp")
# Out:
#         label                                           geometry
# 0     Schaduw  MULTIPOLYGON (((89908.250 472595.250, 89908.25...
# 1  Vegetation  MULTIPOLYGON (((88446.750 471021.750, 88446.75...
# 2       Water  MULTIPOLYGON (((89888.750 472552.250, 89888.75...
# 3        Zand  MULTIPOLYGON (((89916.750 472556.750, 89916.75...

# %%
gdp.read_file("E:/output/Coepelduynen_segmentations_production/20230402_105321_PNEO-03_1_49_30cm_RD_12bit_RGBNED_Zoeterwoude_natura2000_coepelduynen_cropped_ndvi_re_ndvi_asphalt_crop.shp")

# %%
gdp.read_file("E:/output/Coepelduynen_segmentations_production/20230402_105321_PNEO-03_1_49_30cm_RD_12bit_RGBNED_Zoeterwoude_natura2000_coepelduynen_cropped_ndvi_re_ndvi_asphalt_crop_part_0.shp").plot()
# Out:
# <Axes: >

# %%
gdf_explode =gdp.read_file("E:/output/Coepelduynen_segmentations_test/20230402_105321_PNEO-03_1_49_30cm_RD_12bit_RGBNED_Zoeterwoude_natura2000_coepelduynen_cropped_ndvi_re_ndvi_asphalt_crop_part_0_explode.geojson").plot()

# %%
alot_gdf = gdp.read_file("E:/output/Coepelduynen_segmentations_test/20230402_105321_PNEO-03_1_49_30cm_RD_12bit_RGBNED_Zoeterwoude_natura2000_coepelduynen_cropped_ndvi_re_ndvi_asphalt_crop.geojson")

# %%
alot_gdf.to_file("E:/output/Coepelduynen_segmentations_test/20230402_105321_PNEO-03_1_49_30cm_RD_12bit_RGBNED_Zoeterwoude_natura2000_coepelduynen_cropped_ndvi_re_ndvi_asphalt_crop.shp")

# %%
alot_gdf_geometry = alot_gdf['geometry'].explode()
# Out:
# C:\Users\pzhadmin\AppData\Local\Temp\2\ipykernel_8260\3003424770.py:1: FutureWarning: Currently, index_parts defaults to True, but in the future, it will default to False to be consistent with Pandas. Use `index_parts=True` to keep the current behavior and True/False to silence the warning.
#   alot_gdf_geometry = alot_gdf['geometry'].explode()

# %%
alot_gdf_geometry[0] = alot_gdf_geometry[0].buffer(0.3, cap_style=3)

# %%
alot_gdf_geometry[1] = alot_gdf_geometry[1].buffer(0.3, cap_style=3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 alot_gdf_geometry[1] = alot_gdf_geometry[1].buffer(0.3, cap_style=3)
#
# File c:\ProgramData\Anaconda3\envs\py310\envs\py312\Lib\site-packages\geopandas\base.py:3634, in GeoPandasBase.buffer(self, distance, resolution, **kwargs)
#    3628         raise ValueError(
#    3629             "Index values of distance sequence does "
#    3630             "not match index values of the GeoSeries"
#    3631         )
#    3632     distance = np.asarray(distance)
# -> 3634 return _delegate_geo_method(
#    3635     "buffer", self, distance, resolution=resolution, **kwargs
#    3636 )
#
# File c:\ProgramData\Anaconda3\envs\py310\envs\py312\Lib\site-packages\geopandas\base.py:85, in _delegate_geo_method(op, this, *args, **kwargs)
#      82 from .geoseries import GeoSeries
# ...

# %%
alot_gdf_geometry[0] = alot_gdf_geometry[0].unary_union

# %%
alot_gdf_geometry
# Out:
# 0  0          MULTIPOLYGON (((87610.350 469661.850, 87610.35...
#    1          MULTIPOLYGON (((87610.350 469661.850, 87610.35...
#    2          MULTIPOLYGON (((87610.350 469661.850, 87610.35...
#    3          MULTIPOLYGON (((87610.350 469661.850, 87610.35...
#    4          MULTIPOLYGON (((87610.350 469661.850, 87610.35...
#                                     ...
# 1  3781928    POLYGON ((88528.650 470199.150, 88528.650 4701...
#    3781929    POLYGON ((88528.650 470199.450, 88528.650 4701...
#    3781930    POLYGON ((88528.650 470199.750, 88528.650 4701...
#    3781931    POLYGON ((88528.950 470199.450, 88528.950 4701...
#    3781932    POLYGON ((88528.950 470199.750, 88528.950 4701...
# Name: geometry, Length: 3911441, dtype: geometry

# %%
alot_gdf['geometry'].explode().buffer(0.3, cap_style=3)
# Out:
# C:\Users\pzhadmin\AppData\Local\Temp\2\ipykernel_8260\1242524825.py:1: FutureWarning: Currently, index_parts defaults to True, but in the future, it will default to False to be consistent with Pandas. Use `index_parts=True` to keep the current behavior and True/False to silence the warning.
#   alot_gdf['geometry'].explode().buffer(0.3, cap_style=3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 alot_gdf['geometry'].explode().buffer(0.3, cap_style=3)
#
# File c:\ProgramData\Anaconda3\envs\py310\envs\py312\Lib\site-packages\geopandas\base.py:3634, in GeoPandasBase.buffer(self, distance, resolution, **kwargs)
#    3628         raise ValueError(
#    3629             "Index values of distance sequence does "
#    3630             "not match index values of the GeoSeries"
#    3631         )
#    3632     distance = np.asarray(distance)
# ...

# %%
alot_gdf =alot_gdf.to_crs(epsg=3395)
alot_gdf[alot_gdf['label'] == "Sand"]['geometry'] = alot_gdf[alot_gdf['label'] == "Sand"]['geometry'].buffer(0.3, cap_style=3)
alot_gdf[alot_gdf['label'] == "Vegetation"]['geometry'] = alot_gdf[alot_gdf['label'] == "Vegetation"]['geometry'].buffer(0.3, cap_style=3)
alot_gdf = alot_gdf.to_crs(epsg=28992)
gdp.to_file("E:/output/Coepelduynen_segmentations_production/20230601_105710_PNEO-04_1_1_30cm_RD_12bit_RGBNED_Rijnsburg_natura2000_coepelduynen_cropped_ndvi_re_ndvi_asphalt_crop_part_3.shp")
# Out:
# c:\ProgramData\Anaconda3\envs\py310\envs\py312\Lib\site-packages\geopandas\geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
alot_gdf.to_file("E:/output/Coepelduynen_segmentations_production/20230601_105710_PNEO-04_1_1_30cm_RD_12bit_RGBNED_Rijnsburg_natura2000_coepelduynen_cropped_ndvi_re_ndvi_asphalt_crop_part_3.shp")
# Out:
# <Projected CRS: EPSG:28992>
# Name: Amersfoort / RD New
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Netherlands - onshore, including Waddenzee, Dutch Wadden Islands and 12-mile offshore coastal zone.
# - bounds: (3.2, 50.75, 7.22, 53.7)
# Coordinate Operation:
# - name: RD New
# - method: Oblique Stereographic
# Datum: Amersfoort
# - Ellipsoid: Bessel 1841
# - Prime Meridian: Greenwich

# %%
import geopandas as gpd
from shapely.geometry import Polygon

lat_point_list = [50.854457, 52.518172, 50.072651, 48.853033, 50.854457]
lon_point_list = [4.377184, 13.407759, 14.435935, 2.349553, 4.377184]

polygon_geom = Polygon([[lon_point_list[0], lat_point_list[0]], [lon_point_list[1], lat_point_list[1]], [lon_point_list[2], lat_point_list[2]]])
polygon = gpd.GeoDataFrame(index=[0], crs='epsg:4326', geometry=[polygon_geom])       


polygon
# Out:
#                                             geometry
# 0  POLYGON ((4.37718 50.85446, 13.40776 52.51817,...

# %%
zip(lon_point_list, lat_point_list)

# %%
agdf = gpd.read_file("test.shp")

# %%
agdf["geometry"][0:1].values[0]
# Out:
# <POLYGON ((89909.1 472599, 89909.4 472598.7, 89909.1 472598.7, 89909.4 47259...>
